# %% [markdown]
# # Sakura Data Processing (Japan Meteorological Agency)
# The Japan Meteorological Agency (JMA) has a lot more data than JMC does so I'm using their data for processing. Hopefully they have accompanything temperature data that I can use once I get to the modeling stage, otherwise I might
#
# Notes:
# * When I get to the modeling stage, I will probably have to weight recent weather/temperature data higher than old temperature data because of global climate change impacts.
# * Bloom URL's are sakura003_00.html up to sakura003_06.html
# * Full Bloom URL's are sakura004_00.html up to sakura004_06.html
#
# The bottom of the pages have some definitions and notes on the data. I'm using those to determine column names and do some of the translations manually.
#
# For posterity (said notes):
#
#  「*」が現在観測中の地点です。<br>
#  代替種目が空欄の地点はそめいよしのを観測しています。<br>
#  「-」は観測値なしを表しています。<br>
#  平年値は、1981-2010年の平均値です。<br>
#  「#」は、前年に観測したことを表します。<br>
#  (注）倶知安は1994年までえぞやまざくらを、1995年から2006年までそめいよしのを観測していました。
#
# Which rougly translates to
#
# \*: The asteric denotes locations that are currently being observed. <br>
# \-: The dash represents no observation value. <br>
# 平年値: This column is the normal year average from 1981 to 2010. <br>
# \#: This represents that the observation was made in the previous year. <br>
# 注: Until 1994 the observations at Kutchan were Sargent Cherries. From 1995 to 2006 they were Yoshino Cherries.

# %%
import pandas as pd
import numpy as np
import urllib
import requests
from bs4 import BeautifulSoup
import lxml
import time
import re
from io import StringIO
from googletrans import Translator

# %%
# Workaround because I'm on an old version of pandas
pd.set_option("display.max_colwidth", 10000)

# %%
def batch_translation(df, column_src, batch_size=100):
    idx = 0
    while idx < df[column_src].size:
        # Spawn a new translator session to see if that gets past the 429 code from Google.
        translator = Translator()
        translator.raise_Exception = True
        df.loc[idx:idx+batch_size-1,column_src] = df.loc[idx:idx+batch_size-1,column_src].apply(translator.translate, src='ja').apply(getattr, args=('text',))
        idx = idx+batch_size
        print(f"Current index: {idx} of {df[column_src].size}")
        time.sleep(10)

# %%
def extract_sakura_data(url,batch=False,pause_length=2):    
    #colspecs = [(0,5),(5,9),(9,16),(16,23),(23,30),(30,37),(37,44),(44,51),(51,58),(58,65),(65,72),(72,78),(78,86),(86,None)]

    # Be nice to the endpoint and wait a bit if we're doing batch processing of multiple function calls. 
    if batch:
        time.sleep(pause_length)
    bloom_req = requests.get(url)
    bloom_content = BeautifulSoup(bloom_req.content, 'lxml')

    print(f"Processing: {bloom_content.title.text}")
    # Convert the text table to a string IO so that pandas can read it in.
    #print(bloom_content.find(id='main').pre.text)
    bloom_string = StringIO(bloom_content.find(id='main').pre.text)

    #Find the first real line so we can dynmiacally determine the column spacings
    for line in bloom_string:
        if line.isspace() == False:
            break;

    #Find all of the character locations of each year
    year_iter = re.finditer("\d{4}", line)
    year_indices = [(m.start(0),m.end(0)+3) for m in year_iter]

    #Pick the ending character of the last year so we can add the last two columns.
    end_char = year_indices[-1][1]

    dynamic_colspecs = [(0,5),(5,9)]
    end_colspecs = [(end_char,end_char+8),(end_char+8,None)]

    # Put everything together in the same list
    dynamic_colspecs.extend(year_indices)
    dynamic_colspecs.extend(end_colspecs)

    # Reset the string stream so we can re-parse the entire thing.
    bloom_string.seek(0)
    
    
    if debug_print:
        print(bloom_string.getvalue())

    bloom_df = pd.read_fwf(bloom_string,header=2,colspecs=dynamic_colspecs,true_values=['*'])
    if debug_print:
        print(bloom_df.head())

    # Get rid of the extra headers that showed up for readability on a web page.
    bloom_df.columns = bloom_df.columns.str.strip()

    bloom_df[bloom_df.duplicated()]
    bloom_df = bloom_df.drop_duplicates()
    
    bloom_df.drop(bloom_df.loc[bloom_df['地点名'].isna()].index, inplace=True)
    bloom_df.drop(bloom_df[bloom_df['地点名'].str.contains('地点名')].index, inplace=True)

    #Parse the year columns into datetime format.
    for col in bloom_df:
        if str.isnumeric(col):
            # Account for the # entries (which are usually dates measured in december)
            if bloom_df[col].str.contains('#').any():
                last_year = bloom_df[col].str.contains('#',na=False)
                this_year = ~bloom_df[col].str.contains('#',na=False)
                
                bloom_df.loc[last_year,col] = bloom_df.loc[last_year,col] + f' {int(col)-1}'
                bloom_df.loc[this_year,col] = bloom_df.loc[this_year,col] + f' {col}'
                bloom_df[col] = bloom_df[col].str.replace("#","")
            else:
                bloom_df[col] = bloom_df[col] + f' {col}'
            bloom_df[col] = pd.to_datetime(bloom_df[col],errors='coerce',exact=False,format="%m %d %Y")
            
            #   Data Assertion: No dates should exist in the current year after October. If they exist, they should be in the previous year.
            #if bloom_df.loc[bloom_df[col] > pd.to_datetime(f'{col}-10-01'),col].any():
            #    bloom_df.loc[bloom_df[col] > pd.to_datetime(f'{col}-10-01'),col] = bloom_df.loc[bloom_df[col] > f'{col}-10-01',col] - pd.DateOffset(years=1)

    # Translate the non date columns
    bloom_df.rename(columns={bloom_df.columns[0]: 'Site Name',
                          'Unnamed: 1': 'Currently Being Observed',
                          bloom_df.columns[-2]: '30 Year Average 1981-2010',
                          bloom_df.columns[-1]: 'Notes' }, inplace=True)
    
    bloom_df.set_index('Site Name',inplace=True)
    
    #Fix stray #'s
    # Note: There's probably a better way of doing this, but I haven't found it yet.
    bloom_df['30 Year Average 1981-2010'] = bloom_df['30 Year Average 1981-2010'].str.replace("#","")
    
    # Fix the boolean data.
    # There were set values for True, blank got converted into NaN.
    bloom_df['Currently Being Observed'].fillna(False,inplace=True)
    
    with pd.option_context('display.max_rows', None):
        if debug_print:
            display(bloom_df)
            
    return bloom_df

#TODO: Come up with a more descriptive title that isn't super long.
def combine_sakura_data(bloom_dfs):
    
    concated = pd.concat(bloom_dfs,axis=1)
    concated.drop_duplicates(inplace=True)
    
    # Translations
    concated = concated.reset_index()
    concated['Site Name'] = concated['Site Name'] + ', 日本'
    batch_translation(concated,'Site Name',batch_size=10)
    concated['Site Name'] = concated['Site Name'].str.replace(', Japan', "")
    concated.set_index('Site Name',inplace=True)

    # Google translate doesn't properly translate the notes column, so I'm doing that manually.
    notes_dict = {'えぞやまざくら': 'Sargent cherry (Prunus sargentii)',
                  'ちしまざくら': 'Kurile Island Cherry (Cerasus nipponica var. kurilensis)',
                 'ひかんざくら': 'Taiwan cherry (Prunus campanulata)',
                  '（注）': 'Until 1994 Sargent Cherry, from 1995 to 2006 they were Yoshino Cherry.'}
    
    observed_col = concated['Currently Being Observed'].iloc[:,0]
    transposed = concated.T.drop_duplicates(keep='last')
    transposed.drop('Currently Being Observed',inplace=True)

    combined_blooms = transposed.T
    combined_blooms.insert(0,'Currently Being Observed',observed_col);

    combined_blooms.Notes = combined_blooms.Notes.map(notes_dict)
    
    return combined_blooms

# %%
debug_print = False
bloom_urls = ['https://www.data.jma.go.jp/sakura/data/sakura003_00.html',
                     'https://www.data.jma.go.jp/sakura/data/sakura003_01.html',
                     'https://www.data.jma.go.jp/sakura/data/sakura003_02.html',
                     'https://www.data.jma.go.jp/sakura/data/sakura003_03.html',
                     'https://www.data.jma.go.jp/sakura/data/sakura003_04.html',
                     'https://www.data.jma.go.jp/sakura/data/sakura003_05.html',
                     'https://www.data.jma.go.jp/sakura/data/sakura003_06.html',
                     'https://www.data.jma.go.jp/sakura/data/sakura003_07.html']

bloom_dfs = [extract_sakura_data(x,batch=True) for x in bloom_urls]
bloom_start = combine_sakura_data(bloom_dfs)
# Out:
# Processing: 気象庁 | さくらの開花日(1953-1960年)
# Processing: 気象庁 | さくらの開花日(1961-1970年)
# Processing: 気象庁 | さくらの開花日(1971-1980年)
# Processing: 気象庁 | さくらの開花日(1981-1990年)
# Processing: 気象庁 | さくらの開花日(1991-2000年)
# Processing: 気象庁 | さくらの開花日(2001-2010年)
# Processing: 気象庁 | さくらの開花日(2011-2020年)
# Processing: 気象庁 | さくらの開花日(2021-2023年)
# Current index: 10 of 102
# Current index: 20 of 102
# Current index: 30 of 102
# Current index: 40 of 102
# Current index: 50 of 102
# Current index: 60 of 102
# Current index: 70 of 102
# Current index: 80 of 102
# Current index: 90 of 102
# Current index: 100 of 102
# Current index: 110 of 102

# %%
debug_print = False
full_bloom_urls = ['https://www.data.jma.go.jp/sakura/data/sakura004_00.html',
                     'https://www.data.jma.go.jp/sakura/data/sakura004_01.html',
                     'https://www.data.jma.go.jp/sakura/data/sakura004_02.html',
                     'https://www.data.jma.go.jp/sakura/data/sakura004_03.html',
                     'https://www.data.jma.go.jp/sakura/data/sakura004_04.html',
                     'https://www.data.jma.go.jp/sakura/data/sakura004_05.html',
                     'https://www.data.jma.go.jp/sakura/data/sakura004_06.html',
                     'https://www.data.jma.go.jp/sakura/data/sakura004_07.html']

full_bloom_dfs = [extract_sakura_data(x,batch=True) for x in full_bloom_urls]
full_bloom = combine_sakura_data(full_bloom_dfs)
# Out:
# Processing: 気象庁 | さくらの満開日(1953-1960年)
# Processing: 気象庁 | さくらの満開日(1961-1970年)
# Processing: 気象庁 | さくらの満開日(1971-1980年)
# Processing: 気象庁 | さくらの満開日(1981-1990年)
# Processing: 気象庁 | さくらの満開日(1991-2000年)
# Processing: 気象庁 | さくらの満開日(2001-2010年)
# Processing: 気象庁 | さくらの満開日(2011-2020年)
# Processing: 気象庁 | さくらの満開日(2021-2023年)
# Current index: 10 of 102
# Current index: 20 of 102
# Current index: 30 of 102
# Current index: 40 of 102
# Current index: 50 of 102
# Current index: 60 of 102
# Current index: 70 of 102
# Current index: 80 of 102
# Current index: 90 of 102
# Current index: 100 of 102
# Current index: 110 of 102

# %%
# Sanity checks
#    Full bloom is *ALWAYS* after the initial bloom. If it's not something somewhere is wrong.

date_cols = [col for col in bloom_start.columns if str.isnumeric(col)]
broken_dates = full_bloom[date_cols].fillna(pd.Timestamp('2024-01-01')) < bloom_start[date_cols].fillna(pd.Timestamp('1950-01-01'))

broken_dates.any().any()
# Out:
# False

# %%
# Translations Final Fixes
#bloom_start = bloom_start.rename(index={"Iriomotei sand": "Iriomote Island"},errors="raise")
#full_bloom = full_bloom.rename(index={"Iriomotei sand": "Iriomote Island"},errors="raise")

# %%
bloom_start.to_csv('sakura_first_bloom_dates.csv')
full_bloom.to_csv('sakura_full_bloom_dates.csv')

# %% [markdown]
# # Troubleshooting
# This is my area for misc troubleshooting. Fully working code is above this.

# %%
df = bloom_dfs[0].reset_index()
idx = 0
batch_size = 10
column_src = "Site Name"



while idx < df[column_src].size:
    # Spawn a new translator session to see if that gets past the 429 code from Google.
    translator = Translator()
    translator.raise_Exception = True
    df.loc[idx:idx+batch_size,column_src] = df.loc[idx:idx+batch_size,column_src].apply(translator.translate, src='ja').apply(getattr, args=('text',))
    idx = idx+batch_size
    print(f"Current index: {idx} of {df[column_src].size}")
    time.sleep(10)

#df.loc[idx:idx+batch_size,column_src] = df.loc[idx:idx+batch_size,column_src].apply(translator.translate, src='ja').apply(getattr, args=('text',))
#print(f"Current index: {idx} of {df[column_src].size}")
# Out:
# Current index: 10 of 102
# Current index: 20 of 102
# Current index: 30 of 102
# Current index: 40 of 102
# Current index: 50 of 102
# ---------------------------------------------------------------------------
# ReadTimeout                               Traceback (most recent call last)
# <ipython-input-14-9bc818055e10> in <module>
#      10     translator = Translator()
#      11     translator.raise_Exception = True
# ---> 12     df.loc[idx:idx+batch_size,column_src] = df.loc[idx:idx+batch_size,column_src].apply(translator.translate, src='ja').apply(getattr, args=('text',))
#      13     idx = idx+batch_size
#      14     print(f"Current index: {idx} of {df[column_src].size}")
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/pandas/core/series.py in f(x)
#    4183
#    4184             def f(x):
# -> 4185                 return func(x, *args, **kwds)
#    4186
#    4187         else:
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/googletrans/client.py in translate(self, text, dest, src)
#     192
#     193         origin = text
# --> 194         data, response = self._translate(text, dest, src)
#     195
#     196         token_found = False
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/googletrans/client.py in _translate(self, text, dest, src)
#     118             'rt': 'c',
#     119         }
# --> 120         r = self.client.post(url, params=params, data=data)
#     121
#     122         if r.status_code != 200 and self.raise_Exception:
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/httpx/_client.py in post(self, url, data, files, json, params, headers, cookies, auth, allow_redirects, timeout)
#     822         timeout: typing.Union[TimeoutTypes, UnsetType] = UNSET,
#     823     ) -> Response:
# --> 824         return self.request(
#     825             "POST",
#     826             url,
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/httpx/_client.py in request(self, method, url, data, files, json, params, headers, cookies, auth, allow_redirects, timeout)
#     598             cookies=cookies,
#     599         )
# --> 600         return self.send(
#     601             request, auth=auth, allow_redirects=allow_redirects, timeout=timeout,
#     602         )
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/httpx/_client.py in send(self, request, stream, auth, allow_redirects, timeout)
#     618         auth = self.build_auth(request, auth)
#     619
# --> 620         response = self.send_handling_redirects(
#     621             request, auth=auth, timeout=timeout, allow_redirects=allow_redirects,
#     622         )
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/httpx/_client.py in send_handling_redirects(self, request, auth, timeout, allow_redirects, history)
#     645                 raise TooManyRedirects()
#     646
# --> 647             response = self.send_handling_auth(
#     648                 request, auth=auth, timeout=timeout, history=history
#     649             )
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/httpx/_client.py in send_handling_auth(self, request, history, auth, timeout)
#     682         request = next(auth_flow)
#     683         while True:
# --> 684             response = self.send_single_request(request, timeout)
#     685             if auth.requires_response_body:
#     686                 response.read()
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/httpx/_client.py in send_single_request(self, request, timeout)
#     712                 headers,
#     713                 stream,
# --> 714             ) = transport.request(
#     715                 request.method.encode(),
#     716                 request.url.raw,
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py in request(self, method, url, headers, stream, timeout)
#     150
#     151             try:
# --> 152                 response = connection.request(
#     153                     method, url, headers=headers, stream=stream, timeout=timeout
#     154                 )
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/httpcore/_sync/connection.py in request(self, method, url, headers, stream, timeout)
#      76             "connection.request method=%r url=%r headers=%r", method, url, headers
#      77         )
# ---> 78         return self.connection.request(method, url, headers, stream, timeout)
#      79
#      80     def _open_socket(self, timeout: TimeoutDict = None) -> SyncSocketStream:
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/httpcore/_sync/http2.py in request(self, method, url, headers, stream, timeout)
#     116             self.streams[stream_id] = h2_stream
#     117             self.events[stream_id] = []
# --> 118             return h2_stream.request(method, url, headers, stream, timeout)
#     119         except Exception:
#     120             self.max_streams_semaphore.release()
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/httpcore/_sync/http2.py in request(self, method, url, headers, stream, timeout)
#     290
#     291         # Receive the response.
# --> 292         status_code, headers = self.receive_response(timeout)
#     293         reason_phrase = get_reason_phrase(status_code)
#     294         stream = SyncByteStream(
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/httpcore/_sync/http2.py in receive_response(self, timeout)
#     342         """
#     343         while True:
# --> 344             event = self.connection.wait_for_event(self.stream_id, timeout)
#     345             if isinstance(event, h2.events.ResponseReceived):
#     346                 break
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/httpcore/_sync/http2.py in wait_for_event(self, stream_id, timeout)
#     195         with self.read_lock:
#     196             while not self.events[stream_id]:
# --> 197                 self.receive_events(timeout)
#     198         return self.events[stream_id].pop(0)
#     199
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/httpcore/_sync/http2.py in receive_events(self, timeout)
#     202         Read some data from the network, and update the H2 state.
#     203         """
# --> 204         data = self.socket.read(self.READ_NUM_BYTES, timeout)
#     205         events = self.h2_state.receive_data(data)
#     206         for event in events:
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/httpcore/_backends/sync.py in read(self, n, timeout)
#      60             with map_exceptions(exc_map):
#      61                 self.sock.settimeout(read_timeout)
# ---> 62                 return self.sock.recv(n)
#      63
#      64     def write(self, data: bytes, timeout: TimeoutDict) -> None:
#
# ~/anaconda3/envs/mlenv/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     129                 value = type()
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#     133                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/anaconda3/envs/mlenv/lib/python3.8/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#      10         for from_exc, to_exc in map.items():
#      11             if isinstance(exc, from_exc):
# ---> 12                 raise to_exc(exc) from None
#      13         raise
#      14
#
# ReadTimeout: The read operation timed out

# %%
bloom_start = bloom_start.rename(index={"Iriomotei sand": "Iriomote Island"},errors="raise")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c7e4e44d3962> in <module>
# ----> 1 bloom_start = bloom_start.rename(index={"Iriomotei sand": "Iriomote Island"},errors="raise")
#
# NameError: name 'bloom_start' is not defined

# %%
full_bloom
# Out:
#                  Currently Being Observed       1953       1954       1955  \
# Site Name
# Wakkanai                             True 1953-05-30 1954-05-27 1955-05-23
# Rumoi                               False 1953-05-13 1954-05-17 1955-05-16
# Asahikawa                            True 1953-05-16 1954-05-18 1955-05-14
# Abashiri                             True 1953-05-26 1954-05-19 1955-05-20
# Sapporo                              True 1953-05-14 1954-05-08 1955-05-16
# ...                                   ...        ...        ...        ...
# Kumejima                            False        NaT        NaT        NaT
# Naha                                 True        NaT        NaT        NaT
# Nago                                False        NaT        NaT        NaT
# Iriomote Island                     False        NaT        NaT        NaT
# Minamidaitojima                      True        NaT        NaT        NaT
#
#                       1956       1957       1958       1959       1960  \
# Site Name
# Wakkanai        1956-05-14 1957-05-22 1958-05-25 1959-05-12 1960-05-24
# Rumoi           1956-05-14 1957-05-14 1958-05-16        NaT        NaT
# Asahikawa       1956-05-13 1957-05-14 1958-05-15 1959-05-13 1960-05-16
# Abashiri        1956-05-13        NaT        NaT 1959-05-07        NaT
# Sapporo         1956-05-09 1957-05-13        NaT 1959-05-10 1960-05-09
# ...                    ...        ...        ...        ...        ...
# Kumejima               NaT        NaT        NaT        NaT        NaT
# Naha                   NaT        NaT        NaT        NaT        NaT
# Nago                   NaT        NaT        NaT        NaT        NaT
# Iriomote Island        NaT        NaT        NaT        NaT        NaT
# Minamidaitojima        NaT        NaT        NaT        NaT        NaT
#
#                       1961  ...       2013       2014       2015       2016  \
# Site Name                   ...
# Wakkanai        1961-05-18  ... 2013-05-28 2014-05-13 2015-05-06 2016-05-15
# Rumoi           1961-05-13  ...        NaT        NaT        NaT        NaT
# Asahikawa       1961-05-12  ... 2013-05-20 2014-05-04 2015-04-28 2016-05-04
# Abashiri               NaT  ... 2013-05-27 2014-05-11 2015-05-03 2016-05-10
# Sapporo         1961-05-09  ... 2013-05-17 2014-05-01 2015-04-26 2016-05-01
# ...                    ...  ...        ...        ...        ...        ...
# Kumejima               NaT  ...        NaT        NaT        NaT        NaT
# Naha                   NaT  ... 2013-01-23 2014-01-27 2015-01-29 2016-02-12
# Nago                   NaT  ...        NaT        NaT        NaT        NaT
# Iriomote Island        NaT  ...        NaT        NaT        NaT        NaT
# Minamidaitojima        NaT  ... 2013-01-21 2014-01-22 2015-02-13 2016-03-01
#
#                       2017       2018       2019       2020  \
# Site Name
# Wakkanai        2017-05-11 2018-05-15 2019-05-09 2020-05-12
# Rumoi                  NaT        NaT        NaT        NaT
# Asahikawa       2017-05-05 2018-05-01 2019-05-04 2020-05-04
# Abashiri        2017-05-07 2018-05-06 2019-05-07 2020-05-09
# Sapporo         2017-05-03 2018-04-29 2019-04-29 2020-05-02
# ...                    ...        ...        ...        ...
# Kumejima               NaT        NaT        NaT        NaT
# Naha            2017-02-08 2018-01-30 2019-02-12 2020-02-03
# Nago                   NaT        NaT        NaT        NaT
# Iriomote Island        NaT        NaT        NaT        NaT
# Minamidaitojima 2017-02-14 2018-01-29 2019-02-12        NaT
#
#                 30 Year Average 1981-2010                               Notes
# Site Name
# Wakkanai                             5 17   Sargent cherry (Prunus sargentii)
# Rumoi                                   -   Sargent cherry (Prunus sargentii)
# Asahikawa                            5  7   Sargent cherry (Prunus sargentii)
# Abashiri                             5 14   Sargent cherry (Prunus sargentii)
# Sapporo                              5  7                                 NaN
# ...                                   ...                                 ...
# Kumejima                                -  Taiwan cherry (Prunus campanulata)
# Naha                                 2  4  Taiwan cherry (Prunus campanulata)
# Nago                                    -  Taiwan cherry (Prunus campanulata)
# Iriomote Island                         -  Taiwan cherry (Prunus campanulata)
# Minamidaitojima                      2  2  Taiwan cherry (Prunus campanulata)
#
# [102 rows x 71 columns]

# %%
full_bloom[full_bloom[date_cols].fillna(pd.Timestamp('2020-01-02')) < bloom_start[date_cols].fillna(pd.Timestamp('2020-01-01'))]
# Out:
#                  Currently Being Observed 1953 1954 1955 1956 1957 1958 1959  \
# Site Name
# Wakkanai                              NaN  NaT  NaT  NaT  NaT  NaT  NaT  NaT
# Rumoi                                 NaN  NaT  NaT  NaT  NaT  NaT  NaT  NaT
# Asahikawa                             NaN  NaT  NaT  NaT  NaT  NaT  NaT  NaT
# Abashiri                              NaN  NaT  NaT  NaT  NaT  NaT  NaT  NaT
# Sapporo                               NaN  NaT  NaT  NaT  NaT  NaT  NaT  NaT
# ...                                   ...  ...  ...  ...  ...  ...  ...  ...
# Kumejima                              NaN  NaT  NaT  NaT  NaT  NaT  NaT  NaT
# Naha                                  NaN  NaT  NaT  NaT  NaT  NaT  NaT  NaT
# Nago                                  NaN  NaT  NaT  NaT  NaT  NaT  NaT  NaT
# Iriomotei sand                        NaN  NaT  NaT  NaT  NaT  NaT  NaT  NaT
# Minamidaitojima                       NaN  NaT  NaT  NaT  NaT  NaT  NaT  NaT
#
#                 1960 1961  ... 2013 2014 2015 2016 2017 2018 2019 2020  \
# Site Name                  ...
# Wakkanai         NaT  NaT  ...  NaT  NaT  NaT  NaT  NaT  NaT  NaT  NaT
# Rumoi            NaT  NaT  ...  NaT  NaT  NaT  NaT  NaT  NaT  NaT  NaT
# Asahikawa        NaT  NaT  ...  NaT  NaT  NaT  NaT  NaT  NaT  NaT  NaT
# Abashiri         NaT  NaT  ...  NaT  NaT  NaT  NaT  NaT  NaT  NaT  NaT
# Sapporo          NaT  NaT  ...  NaT  NaT  NaT  NaT  NaT  NaT  NaT  NaT
# ...              ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# Kumejima         NaT  NaT  ...  NaT  NaT  NaT  NaT  NaT  NaT  NaT  NaT
# Naha             NaT  NaT  ...  NaT  NaT  NaT  NaT  NaT  NaT  NaT  NaT
# Nago             NaT  NaT  ...  NaT  NaT  NaT  NaT  NaT  NaT  NaT  NaT
# Iriomotei sand   NaT  NaT  ...  NaT  NaT  NaT  NaT  NaT  NaT  NaT  NaT
# Minamidaitojima  NaT  NaT  ...  NaT  NaT  NaT  NaT  NaT  NaT  NaT  NaT
#
#                 30 Year Average 1981-2010 Notes
# Site Name
# Wakkanai                              NaN   NaN
# Rumoi                                 NaN   NaN
# Asahikawa                             NaN   NaN
# Abashiri                              NaN   NaN
# Sapporo                               NaN   NaN
# ...                                   ...   ...
# Kumejima                              NaN   NaN
# Naha                                  NaN   NaN
# Nago                                  NaN   NaN
# Iriomotei sand                        NaN   NaN
# Minamidaitojima                       NaN   NaN
#
# [102 rows x 71 columns]

# %%
debug_print = True
test_url = 'https://www.data.jma.go.jp/sakura/data/sakura004_00.html'

test_df = extract_sakura_data(test_url)
# Out:
# Processing: 気象庁 | さくらの満開日(1953-1960年)
#
#
# 地点名　     1953   1954   1955   1956   1957   1958   1959   1960   平年値   代替種目
#             月 日  月 日  月 日  月 日  月 日  月 日  月 日  月 日   月 日
#
# 稚内     *   5 30   5 27   5 23   5 14   5 22   5 25   5 12   5 24    5 17    えぞやまざくら
# 留萌         5 13   5 17   5 16   5 14   5 14   5 16      -      -       -    えぞやまざくら
# 旭川     *   5 16   5 18   5 14   5 13   5 14   5 15   5 13   5 16    5  7    えぞやまざくら
# 網走     *   5 26   5 19   5 20   5 13      -      -   5  7      -    5 14    えぞやまざくら
# 札幌     *   5 14   5  8   5 16   5  9   5 13      -   5 10   5  9    5  7
# 岩見沢       5 11   5  9   5 13   5  9      -   5 14      -   5 15       -    えぞやまざくら
# 帯広     *   5 19   5 12   5 14   5  9   5 14   5 16   5  5   5 15    5  7    えぞやまざくら
# 高松     *   4  8   4  6   4  7   4 10   4 12   4  7   4  3   4  6    4  5
# 宇和島          -      -      -      -      -      -      -      -       -
# 高知     *      -      -   3 28   3 31   4  7      -   4  1   4  3    3 30
# 徳島     *   4  5   4  5   4  4   4  7   4 10   4  6   4  3   4  3    4  5
#
# 地点名　     1953   1954   1955   1956   1957   1958   1959   1960   平年値   代替種目
#             月 日  月 日  月 日  月 日  月 日  月 日  月 日  月 日   月 日
#
# 下関     *   4 10   4  6   4  5   4  9   4 11   4  8   4  5   4  6    4  5
# 厳原         4  8   4  2   4  4   4 12   4 10   4  6   3 30   4  3       -
# 福岡     *   4  5   4  8   4  5   4  9   4  8   4  5   4  1   3 31    4  1
# 佐賀     *   4  9   4  5   4  4   4  4   4  7   4  4   3 31   4  8    4  3
# 大分     *   4  6   4  3   4  2   4  9   4  9   4  7   4  2   4  5    4  3
# 福江         4  6   4  7   4  2   4  7   4  7   4  3   4  1   4  4       -
# 長崎     *   4  6   4  5   3 31   4  5   4 10   3 28   3 30   4  2    4  3
# 熊本     *   4  4   4  4   3 30   4  1   4  7   4  4   3 29   3 30    4  1
# 延岡            -      -      -      -      -      -      -      -       -
# 鹿児島   *   4  8   4  8   4  3   4  2   4  7   4  3   3 30   4  3    4  4
#
# 宮崎     *   4  3   4  6   4  4   4  4   4  3   3 30   3 30   3 29    4  2
# 屋久島          -      -      -      -      -      -      -      -       -
# 種子島       4  3      -      -      -      -   4  5   4  9   4  5       -
# 名瀬     *   2  2      -      -   1 24   1 31      -   2 12   2  5    1 30    ひかんざくら
# 与那国島        -      -      -      -      -      -      -      -       -    ひかんざくら
# 石垣島   *      -      -      -      -      -   1 27   2  2      -    2  5    ひかんざくら
# 宮古島   *      -   2 14      -   2 10   1 25   1 28   2  4      -    2  9    ひかんざくら
# 久米島          -      -      -      -      -      -      -      -       -    ひかんざくら
# 那覇     *      -      -      -      -      -      -      -      -    2  4    ひかんざくら
# 名護            -      -      -      -      -      -      -      -       -    ひかんざくら
#
# 地点名　     1953   1954   1955   1956   1957   1958   1959   1960   平年値   代替種目
#             月 日  月 日  月 日  月 日  月 日  月 日  月 日  月 日   月 日
#
# 西表島          -      -      -      -      -      -      -      -       -    ひかんざくら
# 南大東島 *      -      -      -      -      -      -      -      -    2  2    ひかんざくら
#           Currently Being Observed       1953       1954       1955  \
# Site Name
# 稚内                            True 1953-05-30 1954-05-27 1955-05-23
# 留萌                             NaN 1953-05-13 1954-05-17 1955-05-16
# 旭川                            True 1953-05-16 1954-05-18 1955-05-14
# 網走                            True 1953-05-26 1954-05-19 1955-05-20
# 札幌                            True 1953-05-14 1954-05-08 1955-05-16
# 岩見沢                            NaN 1953-05-11 1954-05-09 1955-05-13
# 帯広                            True 1953-05-19 1954-05-12 1955-05-14
# 釧路                            True        NaT 1954-05-28 1955-05-26
# 根室                             NaN        NaT        NaT        NaT
# 室蘭                            True 1953-05-17 1954-05-13 1955-05-23
# 浦河                             NaN 1953-05-14 1954-05-13 1955-05-15
# 江差                             NaN 1953-05-15 1954-05-08 1955-05-08
# 宮崎        1956-04-04 1957-04-03 1958-03-30 1959-03-30 1960-03-29
# 屋久島              NaT        NaT        NaT        NaT        NaT
# 種子島              NaT        NaT 1958-04-05 1959-04-09 1960-04-05
# 名瀬        1956-01-24 1957-01-31        NaT 1959-02-12 1960-02-05
# 与那国島             NaT        NaT        NaT        NaT        NaT
# 石垣島              NaT        NaT 1958-01-27 1959-02-02        NaT
# 宮古島       1956-02-10 1957-01-25 1958-01-28 1959-02-04        NaT
# 久米島              NaT        NaT        NaT        NaT        NaT
# 那覇               NaT        NaT        NaT        NaT        NaT
# 名護               NaT        NaT        NaT        NaT        NaT
# 西表島              NaT        NaT        NaT        NaT        NaT
# 南大東島             NaT        NaT        NaT        NaT        NaT
#
#           30 Year Average 1981-2010    Notes
# Site Name
# 稚内                             5 17  えぞやまざくら
# 留萌                                -  えぞやまざくら
# 旭川                             5  7  えぞやまざくら
# 網走                             5 14  えぞやまざくら
# 札幌                             5  7      NaN
# 岩見沢                               -  えぞやまざくら
# 帯広                             5  7  えぞやまざくら
# 釧路                             5 20  えぞやまざくら
# 根室                                -   ちしまざくら
# 室蘭                             5 11      NaN
# 浦河                                -  えぞやまざくら
# 江差                                -      NaN
# 函館                             5  4      NaN
# 倶知安                               -      （注）
# 紋別                                -  えぞやまざくら
# 広尾                                -  えぞやまざくら
# 新庄                                -      NaN
# 青森                             4 29      NaN
# 八戸                                -      NaN
# 秋田                             4 22      NaN
# 盛岡                             4 25      NaN
# 宮古                                -      NaN
# 酒田                                -      NaN
# 山形                             4 19      NaN
# 仙台                             4 16      NaN
# 福島                             4 13      NaN
# 白河                                -      NaN
# 小名浜                               -      NaN
# 輪島                                -      NaN
# 相川                                -      NaN
# 新潟                             4 14      NaN
# 金沢                             4 10      NaN
# 富山                             4 10      NaN
# 長野                             4 17      NaN
# 高田                                -      NaN
# 宇都宮                            4  8      NaN
# 福井                             4  9      NaN
# 高山                                -      NaN
# 松本                                -      NaN
# 前橋                             4  6      NaN
# 熊谷                             4  5      NaN
# 水戸                             4  8      NaN
# 敦賀                                -      NaN
# 岐阜                             4  4      NaN
# 名古屋                            4  3      NaN
# 飯田                                -      NaN
# 甲府                             4  3      NaN
# 銚子                             4  8      NaN
# 津                              4  5      NaN
# 浜松                                -      NaN
# 静岡                             4  3      NaN
# 東京                             4  3      NaN
# 尾鷲                                -      NaN
# 横浜                             4  3      NaN
# 館山                                -      NaN
# 大島                                -      NaN
# 三宅島                               -      NaN
# 八丈島                               -      NaN
# 西郷                                -      NaN
# 松江                             4  8      NaN
# 米子                                -      NaN
# 鳥取                             4  7      NaN
# 豊岡                                -      NaN
# 舞鶴                             4  8      NaN
# 浜田                                -      NaN
# 京都                             4  5      NaN
# 彦根                             4  9      NaN
# 広島                             4  4      NaN
# 岡山                             4  6      NaN
# 神戸                             4  5      NaN
# 大阪                             4  5      NaN
# 洲本                                -      NaN
# 和歌山                            4  4      NaN
# 潮岬                                -      NaN
# 奈良                             4  5      NaN
# 松山                             4  4      NaN
# 高松                             4  5      NaN
# 宇和島                               -      NaN
# 高知                             3 30      NaN
# 徳島                             4  5      NaN
# 下関                             4  5      NaN
# 厳原                                -      NaN
# 福岡                             4  1      NaN
# 佐賀                             4  3      NaN
# 大分                             4  3      NaN
# 福江                                -      NaN
# 長崎                             4  3      NaN
# 熊本                             4  1      NaN
# 延岡                                -      NaN
# 鹿児島                            4  4      NaN
# 宮崎                             4  2      NaN
# 屋久島                               -      NaN
# 種子島                               -      NaN
# 名瀬                             1 30   ひかんざくら
# 与那国島                              -   ひかんざくら
# 石垣島                            2  5   ひかんざくら
# 宮古島                            2  9   ひかんざくら
# 久米島                               -   ひかんざくら
# 那覇                             2  4   ひかんざくら
# 名護                                -   ひかんざくら
# 西表島                               -   ひかんざくら
# 南大東島                           2  2   ひかんざくら

# %%
test_df['Currently Being Observed'].fillna(False,inplace=True)
test_df.head()
# Out:
#            Currently Being Observed       1953       1954       1955  \
# Site Name
# 稚内                             True 1953-05-30 1954-05-27 1955-05-23
# 留萌                            False 1953-05-13 1954-05-17 1955-05-16
# 旭川                             True 1953-05-16 1954-05-18 1955-05-14
# 網走                             True 1953-05-26 1954-05-19 1955-05-20
# 札幌                             True 1953-05-14 1954-05-08 1955-05-16
#
#                 1956       1957       1958       1959       1960  \
# Site Name
# 稚内        1956-05-14 1957-05-22 1958-05-25 1959-05-12 1960-05-24
# 留萌        1956-05-14 1957-05-14 1958-05-16        NaT        NaT
# 旭川        1956-05-13 1957-05-14 1958-05-15 1959-05-13 1960-05-16
# 網走        1956-05-13        NaT        NaT 1959-05-07        NaT
# 札幌        1956-05-09 1957-05-13        NaT 1959-05-10 1960-05-09
#
#           30 Year Average 1981-2010    Notes
# Site Name
# 稚内                             5 17  えぞやまざくら
# 留萌                                -  えぞやまざくら
# 旭川                             5  7  えぞやまざくら
# 網走                             5 14  えぞやまざくら
# 札幌                             5  7      NaN

# %%
translator = Translator()

notes_map = pd.DataFrame(bloom_start['Notes'].unique(), columns=['jp'])

notes_map['en'] = notes_map['jp'].apply(translator.translate).apply(getattr, args=('text',))

# %%
notes_map
# Out:
#         jp               en
# 0  えぞやまざくら   Ezo Yamazakura
# 1      NaN              NaN
# 2   ちしまざくら  Chishima Sakura
# 3      （注）           (Note)
# 4   ひかんざくら      Hikanzakura

# %%
notes_dict = {'えぞやまざくら': 'Sargent cherry (Prunus sargentii)',
              'ちしまざくら': 'Kurile Island Cherry (Cerasus nipponica var. kurilensis)',
             'ひかんざくら': 'Taiwan cherry (Prunus campanulata)',
              '（注）': 'Note: Translation pending'}

# %%
concated['Currently Being Observed'].iloc[:,0]
# Out:
# Site Name
# Wakkanai           True
# Rumoi               NaN
# Asahikawa          True
# Abashiri           True
# Sapporo            True
#                    ...
# Kumejima            NaN
# Naha               True
# Nago                NaN
# Iriomotei sand      NaN
# Minamidaitojima    True
# Name: Currently Being Observed, Length: 102, dtype: object

# %%
trans = Translator()
trans.translate('山形').src
# Out:
# 'ja'

# %%
with pd.option_context('display.max_rows', None):
    display(transposed.T['30 Year Average 1981-2010'])
# Out:
# Site Name
# Wakkanai           5 14
# Rumoi                 -
# Asahikawa          5  5
# Abashiri           5 11
# Sapporo            5  3
# Iwamizawa             -
# Obihiro            5  4
# Kushiro            5 17
# Nemuro                -
# Muroran            5  6
# Urakawa               -
# Esashi                -
# Hakodate           4 30
# Kutchan               -
# Monbetsu              -
# Hiroo                 -
# Shinjo                -
# Aomori             4 24
# Hachinohe             -
# Akita              4 18
# Morioka            4 21
# Miyako                -
# Sakata                -
# Yamagata           4 15
# Sendai             4 11
# Fukushima          4  9
# Shirakawa             -
# Onahama               -
# Wajima                -
# Aikawa                -
# Niigata            4  9
# Kanazawa           4  4
# Toyama             4  5
# Nagano             4 13
# Takada                -
# Utsunomiya         4  1
# Fukui              4  3
# Takayama              -
# Matsumoto             -
# Maebashi           3 31
# Kumagaya           3 29
# Mito               4  2
# Tsuruga               -
# Gifu               3 26
# Nagoya             3 26
# Iida                  -
# Kofu               3 27
# Choshi             3 31
# Tsu                3 30
# Hamamatsu             -
# Shizuoka           3 25
# Tokyo              3 26
# Owase                 -
# Yokohama           3 26
# Tateyama              -
# Oshima                -
# Miyakejima            -
# Hachijojima           -
# Saigo                 -
# Matsue             3 31
# Yonago                -
# Tottori            3 31
# Toyooka               -
# Maizuru            4  3
# Hamada                -
# Kyoto              3 28
# Hikone             4  2
# Hiroshima          3 27
# Okayama            3 29
# Kobe               3 28
# Osaka              3 28
# Sumoto                -
# Wakayama           3 26
# Shionomisaki          -
# Nara               3 29
# Matsuyama          3 25
# Takamatsu          3 28
# Uwajima               -
# Kochi              3 22
# Tokushima          3 28
# Shimonoseki        3 27
# Izuhara               -
# Fukuoka            3 23
# Saga               3 24
# Oita               3 24
# Fukue                 -
# Nagasaki           3 24
# Kumamoto           3 23
# Nobeoka               -
# Kagoshima          3 26
# Miyazaki           3 24
# Yakushima             -
# Tanegashima           -
# Naze               1 19
# Yonaguni Island       -
# Ishigaki Island    1 16
# Miyakojima         1 16
# Kumejima              -
# Naha               1 18
# Nago                  -
# Iriomotei sand        -
# Minamidaitojima    1 20
# Name: 30 Year Average 1981-2010, dtype: object

# %%
with pd.option_context('display.max_rows', None):
    print(concated.loc[['津']].T)
# Out:
# Site Name                                    津
# Currently Being Observed                  True
# 1953                                       NaT
# 1954                       1954-03-03 00:00:00
# 1955                       1955-03-03 00:00:00
# 1956                                       NaT
# 1957                                       NaT
# 1958                                       NaT
# 1959                       1959-03-02 00:00:00
# 1960                       1960-03-02 00:00:00
# 30 Year Average 1981-2010             8    3 3
# Notes                                        0
# Currently Being Observed                  True
# 1961                                       NaT
# 1962                                       NaT
# 1963                                       NaT
# 1964                                       NaT
# 1965                       1965-04-01 00:00:00
# 1966                       1966-03-02 00:00:00
# 1967                       1967-03-03 00:00:00
# 1968                                       NaT
# 1969                                       NaT
# 1970                       1970-04-01 00:00:00
# 30 Year Average 1981-2010             2    3 3
# Notes                                        0
# Currently Being Observed                  True
# 1971                                       NaT
# 1972                                       NaT
# 1973                                       NaT
# 1974                                       NaT
# 1975                                       NaT
# 新庄        1990-04-13                         -      NaN
# 青森        1990-04-15                      4 24      NaN
# 八戸        1990-04-12                         -      NaN
# 秋田        1990-04-10                      4 18      NaN
# 盛岡        1990-04-13                      4 21      NaN
# 宮古        1990-04-11                         -      NaN
# 酒田        1990-04-07                         -      NaN
# 山形        1990-04-09                      4 15      NaN
# 仙台        1990-04-03                      4 11      NaN
# 福島        1990-04-03                      4  9      NaN
# 白河        1990-04-08                         -      NaN
# 小名浜       1990-03-30                         -      NaN
# 輪島        1990-04-02                         -      NaN
# 相川        1990-04-04                         -      NaN
# 新潟        1990-04-01                      4  9      NaN
# 金沢        1990-03-28                      4  4      NaN
# 富山        1990-04-01                      4  5      NaN
# 長野        1990-04-07                      4 13      NaN
# 高田        1990-04-01                         -      NaN
# 宇都宮       1990-03-25                      4  1      NaN
# 福井        1990-03-27                      4  3      NaN
# 高山        1990-04-09                         -      NaN
# 松本        1990-04-04                         -      NaN
# 前橋        1990-03-24                      3 31      NaN
# 熊谷        1990-03-22                      3 29      NaN
# 水戸        1990-03-25                      4  2      NaN
# 敦賀        1990-03-25                         -      NaN
# 岐阜        1990-03-17                      3 26      NaN
# 名古屋       1990-03-17                      3 26      NaN
# 飯田        1990-03-28                         -      NaN
# 甲府        1990-03-20                      3 27      NaN
# 銚子        1990-03-21                      3 31      NaN
# 津         1990-03-22                      3 30      NaN
# 浜松        1990-03-17                         -      NaN
# 静岡        1990-03-20                      3 25      NaN
# 東京        1990-03-20                      3 26      NaN
# 尾鷲        1990-03-20                         -      NaN
# 横浜        1990-03-18                      3 26      NaN
# 館山        1990-03-20                         -      NaN
# 大島        1990-03-20                         -      NaN
# 三宅島       1990-03-20                         -      NaN
# 八丈島       1990-03-30                         -      NaN
# 西郷        1990-03-27                         -      NaN
# 松江        1990-03-24                      3 31      NaN
# 米子        1990-03-24                         -      NaN
# 鳥取        1990-03-24                      3 31      NaN
# 豊岡        1990-03-28                         -      NaN
# 舞鶴        1990-03-26                      4  3      NaN
# 浜田        1990-03-20                         -      NaN
# 京都        1990-03-21                      3 28      NaN
# 彦根        1990-03-23                      4  2      NaN
# 広島        1990-03-20                      3 27      NaN
# 岡山        1990-03-23                      3 29      NaN
# 神戸        1990-03-21                      3 28      NaN
# 大阪        1990-03-21                      3 28      NaN
# 洲本        1990-03-21                         -      NaN
# 和歌山       1990-03-19                      3 26      NaN
# 潮岬        1990-03-23                         -      NaN
# 奈良        1990-03-23                      3 29      NaN
# 松山        1990-03-18                      3 25      NaN
# 高松        1990-03-21                      3 28      NaN
# 宇和島       1990-03-15                         -      NaN
# 高知        1990-03-14                      3 22      NaN
# 徳島        1990-03-21                      3 28      NaN
# 下関        1990-03-20                      3 27      NaN
# 厳原        1990-03-18                         -      NaN
# 福岡        1990-03-14                      3 23      NaN
# 佐賀        1990-03-17                      3 24      NaN
# 大分        1990-03-16                      3 24      NaN
# 福江        1990-03-19                         -      NaN
# 長崎        1990-03-15                      3 24      NaN
# 熊本        1990-03-17                      3 23      NaN
# 延岡        1990-03-21                         -      NaN
bloom_req = requests.get('https://www.data.jma.go.jp/sakura/data/sakura003_03.html')
bloom_content = BeautifulSoup(bloom_req.content, 'lxml')

# Convert the text table to a string IO so that pandas can read it in.
#print(bloom_content.find(id='main').pre.text)
bloom_string = StringIO(bloom_content.find(id='main').pre.text)

String = '地点名　     1953   1954   1955   1956   1957   1958   1959   1960   平年値   代替種目'
String2 = '地点名　     2011   2012   2013   2014   2015   2016   2017   2018   2019   2020   平年値   代替種目'

#Find the first real line so we can dynmiacally determine the column spacings
for line in bloom_string:
    if line.isspace() == False:
        break;

#Find all of the character locations of each year
year_iter = re.finditer("\d{4}", line)
year_indices = [(m.start(0),m.end(0)+3) for m in year_iter]

#Pick the ending character of the last year so we can add the last two columns.
end_char = year_indices[-1][1]

dynamic_colspecs = [(0,5),(5,9)]
end_colspecs = [(end_char,end_char+8),(end_char+8,None)]

# Put everything together in the same list
dynamic_colspecs.extend(year_indices)
dynamic_colspecs.extend(end_colspecs)

print(dynamic_colspecs)
# Reset the string stream so we can re-parse the entire thing.
bloom_string.seek(0)

if debug_print:
    print(bloom_string.getvalue())

tst_names = ['地点名', 'Unnamed: 1', '1953', '1954', '1955','1956','1957','1958','1959','1960','平年値','代替種目']
unparsed_data = pd.read_fwf(bloom_string,header=0,colspecs=dynamic_colspecs,true_values=['*'])
with pd.option_context('display.max_rows', None):
    if debug_print:
        display(unparsed_data)
# Out:
# [(0, 5), (5, 9), (9, 16), (16, 23), (23, 30), (30, 37), (37, 44), (44, 51), (51, 58), (58, 65), (65, 72), (72, 79), (79, 87), (87, None)]
#
#
# 地点名　     1981   1982   1983   1984   1985   1986   1987   1988   1989   1990   平年値   代替種目
#             月 日  月 日  月 日  月 日  月 日  月 日  月 日  月 日  月 日  月 日   月 日
#
# 稚内     *   5 11   5 16   5  6   5 24   5 13   5 13   5 16   5 15   5 16   5  6    5 14    えぞやまざくら
# 留萌         5  9   5 10   4 30   5 22   5 11   5  9   5  9   5  9   5  3   4 26       -    えぞやまざくら
# 旭川     *   5  5   5  5   4 27   5 14   5  3   5  6   5  9   5  7   5  3   4 28    5  5    えぞやまざくら
# 網走     *   5 14   5 11   5  3   5 24   5 10   5  8   5  9   5 12   5 16   5  7    5 11    えぞやまざくら
# 札幌     *   5  5   5  4   4 28   5 12   5  3   5  5   5  6   5  3   4 29   4 25    5  3
# 岩見沢       5  7   5  5   4 27   5 17   5  4   5  5   5  8   5  5   4 28   4 26       -    えぞやまざくら
# 帯広     *   5  4   5  6   5  1   5 19   5  3   5  6   5  4   5  4   5  5   5  1    5  4    えぞやまざくら
# 釧路     *   5 22   5 17   5 12   5 30   5 18   5 16   5 17   5 18   5 18   5 10    5 17    えぞやまざくら
# 根室         5 24   5 19   5 15   5 30   5 19   5 19   5 15   5 22   5 20   5 11       -    ちしまざくら
# 室蘭     *   5  6   5 10   4 29   5 25   5 10   5  8   5  9   5  6   4 30   4 26    5  6
#
# 浦河         5 12   5 13   5  5   5 25   5 12   5 10   5 12   5 12   5  8   5  6       -    えぞやまざくら
# 48    4  3    3 16    3 17      3 26      NaN
# 49    4  3    3 17    3 17      3 26      NaN
# 50    4 14    3 29    3 28         -      NaN
# 51    4  4    3 25    3 20      3 27      NaN
# 52    4  3    3 20    3 21      3 31      NaN
# 53    4  5    3 25    3 22      3 30      NaN
# 54    4  3    3 21    3 17         -      NaN
# 55    4  3    3 21    3 20      3 25      NaN
# 56    4  2    3 20    3 20      3 26      NaN
# 57    3 30    3 17    3 20         -      NaN
# 58    4  2    3 21    3 18      3 26      NaN
# 59    4  5    3 25    3 20         -      NaN
# 60    4  5    3 22    3 20         -      NaN
# 61    4  4    3 16    3 20         -      NaN
# 62    4  3    3 29    3 30         -      NaN
# 63    4 11    3 30    3 27         -      NaN
# 64    4 10    3 28    3 24      3 31      NaN
# 65    1988    1989    1990  平年値   代替       種目
# 66   日   月       日     NaN       NaN      NaN
# 67    4 11    3 29    3 24         -      NaN
# 68    4 11    3 29    3 24      3 31      NaN
# 69    4 13    3 30    3 28         -      NaN
# 70    4 12    3 30    3 26      4  3      NaN
# 71    4  6    3 26    3 20         -      NaN
# 72    4  5    3 24    3 21      3 28      NaN
# 73    4  7    3 30    3 23      4  2      NaN
# 74    4  3    3 25    3 20      3 27      NaN
# 75    4  5    3 26    3 23      3 29      NaN
# 76    4  5    3 25    3 21      3 28      NaN
# 77    4  5    3 25    3 21      3 28      NaN
# 78    4  6    3 19    3 21         -      NaN
# 79    4  5    3 20    3 19      3 26      NaN
# 80    4  5    3 20    3 23         -      NaN
# 81    4  7    3 25    3 23      3 29      NaN
# 82    4  3    3 21    3 18      3 25      NaN
# 83    4  5    3 24    3 21      3 28      NaN
# 84    4  2    3 15    3 15         -      NaN
# 85    3 28    3 15    3 14      3 22      NaN
# 86    4  5    3 23    3 21      3 28      NaN
# 87    1988    1989    1990  平年値   代替       種目
# 88   日   月       日     NaN       NaN      NaN
# 89    4  4    3 22    3 20      3 27      NaN
# 90    4  2    3 22    3 18         -      NaN
# 91    4  2    3 17    3 14      3 23      NaN
# 92    4  2    3 20    3 17      3 24      NaN
# 93    4  2    3 20    3 16      3 24      NaN
# 94    4  1    3 22    3 19         -      NaN
# 95    4  1    3 18    3 15      3 24      NaN
# 96    4  1    3 18    3 17      3 23      NaN
# 97    4  2    3 16    3 21         -      NaN
# 98    4  3    3 25    3 22      3 26      NaN
# 99    4  2    3 22    3 19      3 24      NaN
# 100      -       -       -         -      NaN
# 101   3 31    3 22    3 19         -      NaN
# 102   1 12    1  6    1 14      1 19   ひかんざくら
# 103      -       -       -         -   ひかんざくら
# 104   1  1  12 27#    1  5      1 16   ひかんざくら
# 105   1 17    1  8    1 11      1 16   ひかんざくら
# 106   1  6  12 31#  12 31#         -   ひかんざくら
# 107   1 19    1  9    1 21      1 18   ひかんざくら
# 108   1  4  12 31#  12 30#         -   ひかんざくら
# 109   1988    1989    1990  平年値   代替       種目
# 110  日   月       日     NaN       NaN      NaN
# 111   1 15    1 15    1 18         -   ひかんざくら
# 112   1 29    1 17    1 16      1 20   ひかんざくら

# %%
debug_print = False
testing = process_sakura_url('https://www.data.jma.go.jp/sakura/data/sakura003_03.html')

print(testing.iloc[1])
# Out:
# Processing: 気象庁 | さくらの開花日(1981-1990年)
# Currently Being Observed                     NaN
# 1981                         1981-05-09 00:00:00
# 1982                         1982-05-10 00:00:00
# 1983                         1983-04-30 00:00:00
# 1984                         1984-05-22 00:00:00
# 1985                         1985-05-11 00:00:00
# 1986                         1986-05-09 00:00:00
# 1987                         1987-05-09 00:00:00
# 1988                         1988-05-09 00:00:00
# 1989                         1989-05-03 00:00:00
# 1990                         1990-04-26 00:00:00
# 30 Year Average 1981-2010                      -
# Notes                                    えぞやまざくら
# Name: 留萌, dtype: object

# %%
testing.loc[testing['1989'] > '1989-10-01','1989']
# Out:
# Series([], Name: 1989, dtype: datetime64[ns])

# %%
testing.loc[testing['1989'] < '1989-01-01','1989']
# Out:
# Timestamp('1988-12-29 16:00:00')

# %%
concated.T.loc[concated.T.duplicated()]
# Out:
# Site Name                       稚内       留萌       旭川       網走    札幌      岩見沢  \
# Currently Being Observed      True      NaN     True     True  True      NaN
# Notes                      えぞやまざくら  えぞやまざくら  えぞやまざくら  えぞやまざくら   NaN  えぞやまざくら
# Currently Being Observed      True      NaN     True     True  True      NaN
# Notes                      えぞやまざくら  えぞやまざくら  えぞやまざくら  えぞやまざくら   NaN  えぞやまざくら
# Currently Being Observed      True      NaN     True     True  True      NaN
# Notes                      えぞやまざくら  えぞやまざくら  えぞやまざくら  えぞやまざくら   NaN  えぞやまざくら
# Currently Being Observed      True      NaN     True     True  True      NaN
# Notes                      えぞやまざくら  えぞやまざくら  えぞやまざくら  えぞやまざくら   NaN  えぞやまざくら
# Currently Being Observed      True      NaN     True     True  True      NaN
# Notes                      えぞやまざくら  えぞやまざくら  えぞやまざくら  えぞやまざくら   NaN  えぞやまざくら
# Currently Being Observed      True      NaN     True     True  True      NaN
# 30 Year Average 1981-2010     5 14        -     5  5     5 11  5  3        -
# Notes                      えぞやまざくら  えぞやまざくら  えぞやまざくら  えぞやまざくら   NaN  えぞやまざくら
#
# Site Name                       帯広       釧路      根室    室蘭  ...  種子島      名瀬  \
# Currently Being Observed      True     True     NaN  True  ...  NaN    True
# Notes                      えぞやまざくら  えぞやまざくら  ちしまざくら   NaN  ...  NaN  ひかんざくら
# Currently Being Observed      True     True     NaN  True  ...  NaN    True
# Notes                      えぞやまざくら  えぞやまざくら  ちしまざくら   NaN  ...  NaN  ひかんざくら
# Currently Being Observed      True     True     NaN  True  ...  NaN    True
# Notes                      えぞやまざくら  えぞやまざくら  ちしまざくら   NaN  ...  NaN  ひかんざくら
# Currently Being Observed      True     True     NaN  True  ...  NaN    True
# Notes                      えぞやまざくら  えぞやまざくら  ちしまざくら   NaN  ...  NaN  ひかんざくら
# Currently Being Observed      True     True     NaN  True  ...  NaN    True
# Notes                      えぞやまざくら  えぞやまざくら  ちしまざくら   NaN  ...  NaN  ひかんざくら
# Currently Being Observed      True     True     NaN  True  ...  NaN    True
# 30 Year Average 1981-2010     5  4     5 17       -  5  6  ...    -    1 19
# Notes                      えぞやまざくら  えぞやまざくら  ちしまざくら   NaN  ...  NaN  ひかんざくら
#
# Site Name                    与那国島     石垣島     宮古島     久米島      那覇      名護  \
# Currently Being Observed      NaN    True    True     NaN    True     NaN
# Notes                      ひかんざくら  ひかんざくら  ひかんざくら  ひかんざくら  ひかんざくら  ひかんざくら
# Currently Being Observed      NaN    True    True     NaN    True     NaN
# Notes                      ひかんざくら  ひかんざくら  ひかんざくら  ひかんざくら  ひかんざくら  ひかんざくら
# Currently Being Observed      NaN    True    True     NaN    True     NaN
# Notes                      ひかんざくら  ひかんざくら  ひかんざくら  ひかんざくら  ひかんざくら  ひかんざくら
# Currently Being Observed      NaN    True    True     NaN    True     NaN
# Notes                      ひかんざくら  ひかんざくら  ひかんざくら  ひかんざくら  ひかんざくら  ひかんざくら
# Currently Being Observed      NaN    True    True     NaN    True     NaN
# Notes                      ひかんざくら  ひかんざくら  ひかんざくら  ひかんざくら  ひかんざくら  ひかんざくら
# Currently Being Observed      NaN    True    True     NaN    True     NaN
# 30 Year Average 1981-2010       -    1 16    1 16       -    1 18       -
# Notes                      ひかんざくら  ひかんざくら  ひかんざくら  ひかんざくら  ひかんざくら  ひかんざくら
#
# Site Name                     西表島    南大東島
# Currently Being Observed      NaN    True
# Notes                      ひかんざくら  ひかんざくら
# Currently Being Observed      NaN    True
# Notes                      ひかんざくら  ひかんざくら
# Currently Being Observed      NaN    True
# Notes                      ひかんざくら  ひかんざくら
# Currently Being Observed      NaN    True
# Notes                      ひかんざくら  ひかんざくら
# Currently Being Observed      NaN    True
# Notes                      ひかんざくら  ひかんざくら
# Currently Being Observed      NaN    True
# 30 Year Average 1981-2010       -    1 20
# Notes                      ひかんざくら  ひかんざくら
#
# [13 rows x 102 columns]

# %%
with pd.option_context('display.max_rows', None):
    display(concated.loc['名護','30 Year Average 1981-2010'])
    
concated.loc['名護','30 Year Average 1981-2010'].str.contains('#').any()

derp = '2019'

for entry in concated.loc['名護','30 Year Average 1981-2010']:
    if '#' in entry:
         print(entry)
# Out:
# 30 Year Average 1981-2010           -
# 30 Year Average 1981-2010           -
# 30 Year Average 1981-2010    #      -
# 30 Year Average 1981-2010    #      -
# 30 Year Average 1981-2010           -
# 30 Year Average 1981-2010           -
# 30 Year Average 1981-2010           -
# Name: 名護, dtype: object
# #      -
# #      -

# %%
untransposed = transposed.T

with pd.option_context('display.max_rows', None):
    display(untransposed['30 Year Average 1981-2010'])
# Out:
#           30 Year Average 1981-2010 30 Year Average 1981-2010  \
# Site Name
# 稚内                             5 14                      5 14
# 留萌                                -                         -
# 旭川                             5  5                      5  5
# 網走                             5 11                      5 11
# 札幌                             5  3                      5  3
# 岩見沢                               -                         -
# 帯広                             5  4                      5  4
# 釧路                             5 17                      5 17
# 根室                                -                         -
# 室蘭                             5  6                      5  6
# 浦河                                -                         -
# 江差                                -                         -
# 函館                             4 30                      4 30
# 倶知安                               -                         -
# 紋別                                -                         -
# 広尾                                -                         -
# 新庄                                -                         -
# 酒田                                -                         -
# 山形                             4 15                      4 15
# 仙台                             4 11                      4 11
# 福島                             4  9                      4  9
# 白河                                -                         -
# 小名浜                               -                         -
# 輪島                                -                         -
# 相川                                -                         -
# 新潟                             4  9                      4  9
# 金沢                             4  4                      4  4
# 富山                             4  5                      4  5
# 長野                             4 13                      4 13
# 高田                                -                         -
# 宇都宮                            4  1                      4  1
# 福井                             4  3                      4  3
# 高山                                -                         -
# 松本                                -                         -
# 前橋                             3 31                      3 31
# 熊谷                             3 29                      3 29
# 水戸                             4  2                      4  2
# 敦賀                                -                         -
# 岐阜                             3 26                      3 26
# 名古屋                            3 26                      3 26
# 飯田                                -                         -
# 甲府                             3 27                      3 27
# 銚子                             3 31                      3 31
# 津                          4    3 3                  5    3 3
# 浜松                                -                         -
# 静岡                             3 25                      3 25
# 東京                             3 26                      3 26
# 尾鷲                                -                         -
# 横浜                             3 26                      3 26
# 館山                                -                         -
# 大島                                -                         -
# 三宅島                               -                         -
# 八丈島                               -                         -
# 西郷                                -                         -
# 松江                             3 31                      3 31
# 米子                                -                         -
# 鳥取                             3 31                      3 31
# 豊岡                                -                         -
# 舞鶴                             4  3                      4  3
# 浜田                                -                         -
# 京都                             3 28                      3 28
# 彦根                             4  2                      4  2
# 広島                             3 27                      3 27
# 岡山                             3 29                      3 29
# 神戸                             3 28                      3 28
# 大阪                             3 28                      3 28
# 洲本                                -                         -
# 和歌山                            3 26                      3 26
# 潮岬                                -                         -
# 奈良                             3 29                      3 29
# 松山                             3 25                      3 25
# 高松                             3 28                      3 28
# 宇和島                               -                         -
# 高知                             3 22                      3 22
# 徳島                             3 28                      3 28
# 下関                             3 27                      3 27
# 厳原                                -                         -
# 福岡                             3 23                      3 23
# 佐賀                             3 24                      3 24
# 大分                             3 24                      3 24
# 福江                                -                         -
# 長崎                             3 24                      3 24
# 熊本                             3 23                      3 23
# 延岡                                -                         -
# 鹿児島                            3 26                      3 26
# 宮崎                             3 24                      3 24
# 屋久島                               -                         -
# 種子島                               -                         -
# 名瀬                             1 19                      1 19
# 与那国島                              -                         -
# 石垣島                            1 16                      1 16
# 宮古島                            1 16                      1 16
# 久米島                               -                         -
# 那覇                         #   1 18                      1 18
# 名護                                -                         -
# 西表島                               -                         -
# 南大東島                           1 20                      1 20

# %%
debug_print = True
#process_sakura_url('https://www.data.jma.go.jp/sakura/data/sakura003_01.html')

# %%
col = '1990'

has_stuff = unparsed_data[col].str.contains('#',na=False)
no_stuff = ~unparsed_data[col].str.contains('#',na=False)
#unparsed_data.loc[~unparsed_data[col].str.contains('#',na=False),col] = unparsed_data.loc[~unparsed_data[col].str.contains('#',na=False),col] + f' {int(col)-1}'

# %%
unparsed_data.loc[has_stuff,col] = unparsed_data.loc[has_stuff,col].str.strip('#') + f' {int(col)-1}'

# %%
unparsed_data.loc[has_stuff,'1989'].str.replace("#","")
# Out:
# 106    12 31
# 108    12 31
# Name: 1989, dtype: object

# %%
bloom_content.title.text
# Out:
# '気象庁 | さくらの開花日(1981-1990年)'
